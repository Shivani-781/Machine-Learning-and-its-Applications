# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivani-781/Machine-Learning-and-its-Applications/blob/master/Missing_Values_Imputation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Missing Values Imputation**

# %% [markdown]
# ## **Using Simple Imputer**

# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv("/content/drive/My Drive/ML_Data/Missing data Imputation.csv")
df
# Out:
#     Country   Age   Salary Purchased
# 0    France  44.0  72000.0        No
# 1     Spain  27.0  48000.0       Yes
# 2   Germany  30.0  54000.0        No
# 3     Spain  38.0  61000.0        No
# 4   Germany  40.0      NaN       Yes
# 5    France  35.0  58000.0       Yes
# 6     Spain   NaN  52000.0        No
# 7    France  48.0  79000.0       Yes
# 8   Germany  50.0  83000.0        No
# 9    France  37.0  67000.0       Yes
# 10    India  36.0  65000.0       Yes

# %%
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
imputer = imputer.fit(df.iloc[:, 1:3])
df.iloc[:, 1:3] = imputer.transform(df.iloc[:, 1:3])

# %%
df
# Out:
#     Country   Age   Salary Purchased
# 0    France  44.0  72000.0        No
# 1     Spain  27.0  48000.0       Yes
# 2   Germany  30.0  54000.0        No
# 3     Spain  38.0  61000.0        No
# 4   Germany  40.0  63900.0       Yes
# 5    France  35.0  58000.0       Yes
# 6     Spain  38.5  52000.0        No
# 7    France  48.0  79000.0       Yes
# 8   Germany  50.0  83000.0        No
# 9    France  37.0  67000.0       Yes
# 10    India  36.0  65000.0       Yes

# %% [markdown]
# ## **Using Fillna method**

# %%
df1 = pd.read_csv('/content/drive/My Drive/ML_Data/Missing data Imputation.csv')
df1
# Out:
#     Country   Age   Salary Purchased
# 0    France  44.0  72000.0        No
# 1     Spain  27.0  48000.0       Yes
# 2   Germany  30.0  54000.0        No
# 3     Spain  38.0  61000.0        No
# 4   Germany  40.0      NaN       Yes
# 5    France  35.0  58000.0       Yes
# 6     Spain   NaN  52000.0        No
# 7    France  48.0  79000.0       Yes
# 8   Germany  50.0  83000.0        No
# 9    France  37.0  67000.0       Yes
# 10    India  36.0  65000.0       Yes

# %%
df1.fillna(df1.mean(), inplace=True)
df1
# Out:
#     Country   Age   Salary Purchased
# 0    France  44.0  72000.0        No
# 1     Spain  27.0  48000.0       Yes
# 2   Germany  30.0  54000.0        No
# 3     Spain  38.0  61000.0        No
# 4   Germany  40.0  63900.0       Yes
# 5    France  35.0  58000.0       Yes
# 6     Spain  38.5  52000.0        No
# 7    France  48.0  79000.0       Yes
# 8   Germany  50.0  83000.0        No
# 9    France  37.0  67000.0       Yes
# 10    India  36.0  65000.0       Yes

# %% [markdown]
# ## **Exporting data**

# %%
df.to_csv('/content/drive/My Drive/ML_Data/Country.csv')
